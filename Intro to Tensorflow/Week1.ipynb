# %% [markdown]
# The Whole Things are taught in this week is about in machine learning matter and software We know the **Result** and **Data** the things we need to realize is the **Rule** between these two factors.
#
# ```
# # the main import of a tensorflow program
#
# from tensorflow import keras
# import tensorflow as tf
# import numpy as np
# ```
#
# Then We introduced with a command to solve a simple problem which is learning a linear function between two **x** and **y**.
#
# for creating ke simple neural network we use:
#
#
# ```
# model = keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])
# ```
#
# after that we compile out model with code:
#
#
#
# ```
# model.compile(optimizer = 'sgd', loss='mean_squared_error')
# ```
#
# then fit the model and predict what should be.

# %%
from tensorflow import keras
import tensorflow as tf
import numpy as np

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
x = np.arange(-1, 6)
y = x * 2 - 1

model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 416ms/step - loss: 46.0600
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 32.0547
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 22.4140
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 15.7756
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 11.2026
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.0505
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.8758
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3735
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.3340
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6129
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1109
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7597
# ...

# %%
print(model.predict([10]))
# Out:
# [[18.976341]]
